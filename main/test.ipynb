# %%
import pandas as pd
from raif_hack import preprocessing

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
a = preprocessing.preprocessing(train_df)
# Out:
# (279792, 85)
# (279792, 86)
# (279792, 92)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
salary_data = pd.read_csv('data/salary.csv', delimiter=";")[["Name", "2020"]]
salary_data.rename(columns={"Name":"region", '2020':'salary'}, inplace=True)
salary_data['salary'] = salary_data['salary'].apply(lambda x: float(x.replace(',', '.')) if type(x) == str else x)

city_data = pd.read_csv('data/city.csv')
city_data.rename(columns={'geo_lat':'centre_lat', 'geo_lon':'centre_lng'}, inplace=True)
city_features = ['city', 'fias_level', 'capital_marker', 'centre_lat', 'centre_lng', 'population','federal_district']
city_data.drop_duplicates(subset="city", inplace=True)

# %%
city_data.drop_duplicates(subset="city", inplace=True)

# %%
print(train_df.shape)
b = pd.merge(train_df, salary_data, on='region')
print(b.shape)

b = pd.merge(b, city_data[city_features], on='city', how='left')
print(b.shape)
# Out:
# (279792, 77)
# (279792, 78)
# (279792, 84)

# %%
b
# Out:
#                    city floor          id        lat        lng  \
# 0                 Пермь   NaN       COL_0  57.998207  56.292797
# 1                Шатура   NaN       COL_1  55.574284  39.543835
# 2             Ярославль   NaN       COL_2  57.619140  39.850525
# 3           Новокузнецк   NaN       COL_3  53.897083  87.108604
# 4                Москва   NaN       COL_4  55.802590  37.487110
# ...                 ...   ...         ...        ...        ...
# 283053  Санкт-Петербург   1.0  COL_280479  59.936954  30.356383
# 283054      Калининград   3.0  COL_280518  54.729233  20.514968
# 283055         Кемерово   1.0  COL_280529  55.360680  86.081460
# 283056            Киров   1.0  COL_280637  58.592915  49.677439
# 283057            Киров   1.0  COL_280637  58.592915  49.677439
#
#         osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                                 4                           19
# ...

# %%
train_df
# Out:
#                    city floor          id        lat        lng  \
# 0                 Пермь   NaN       COL_0  57.998207  56.292797
# 1                Шатура   NaN       COL_1  55.574284  39.543835
# 2             Ярославль   NaN       COL_2  57.619140  39.850525
# 3           Новокузнецк   NaN       COL_3  53.897083  87.108604
# 4                Москва   NaN       COL_4  55.802590  37.487110
# ...                 ...   ...         ...        ...        ...
# 279787            Томск   1.0  COL_280111  56.459183  84.979334
# 279788  Санкт-Петербург   1.0  COL_280479  59.936954  30.356383
# 279789      Калининград   3.0  COL_280518  54.729233  20.514968
# 279790         Кемерово   1.0  COL_280529  55.360680  86.081460
# 279791            Киров   1.0  COL_280637  58.592915  49.677439
#
#         osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                                 4                           19
# ...

# %%
b = train_df.merge(city_data[city_features], on='city', how='left')

# %%
b
# Out:
#                    city floor          id        lat        lng  \
# 0                 Пермь   NaN       COL_0  57.998207  56.292797
# 1                Шатура   NaN       COL_1  55.574284  39.543835
# 2             Ярославль   NaN       COL_2  57.619140  39.850525
# 3           Новокузнецк   NaN       COL_3  53.897083  87.108604
# 4                Москва   NaN       COL_4  55.802590  37.487110
# ...                 ...   ...         ...        ...        ...
# 283053  Санкт-Петербург   1.0  COL_280479  59.936954  30.356383
# 283054      Калининград   3.0  COL_280518  54.729233  20.514968
# 283055         Кемерово   1.0  COL_280529  55.360680  86.081460
# 283056            Киров   1.0  COL_280637  58.592915  49.677439
# 283057            Киров   1.0  COL_280637  58.592915  49.677439
#
#         osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                                 4                           19
# ...

# %%
b[pd.isna(b['centre_lat'])]['city'].value_counts()
# Out:
# Москва                                          55996
# Санкт-Петербург                                 18906
# Коммунарка                                        328
# Орел                                              300
# Щёлково                                           145
#                                                 ...
# Киреевский район, пос. Октябрьский                  1
# Домодедово городской округ, с. Красный Путь         1
# Нежинский                                           1
# Лужский район, Заклинское с/пос, д. Заклинье        1
# Краснодар городской округ, пос. Лазурный            1
# Name: city, Length: 4155, dtype: int64

# %%
import numpy as np

# %%
train_df[pd.isna(train_df['salary'])]['region'].value_counts()
# Out:
# Санкт-Петербург        18888
# Татарстан               9064
# Башкортостан            7805
# Ханты-Мансийский АО     3100
# Удмуртия                2647
# Коми                    1669
# Карелия                  969
# Мордовия                 868
# Адыгея                   539
# Алтай                     34
# Name: region, dtype: int64

# %%
train_df = preprocessing.preprocessing(train_df)
# Out:
# (279792, 107)
# (279792, 108)
# (283058, 114)

# %%
train_df
# Out:
#                    city floor          id        lat        lng  \
# 0                 Пермь   NaN       COL_0  57.998207  56.292797
# 1                Шатура   NaN       COL_1  55.574284  39.543835
# 2             Ярославль   NaN       COL_2  57.619140  39.850525
# 3           Новокузнецк   NaN       COL_3  53.897083  87.108604
# 4                Москва   NaN       COL_4  55.802590  37.487110
# ...                 ...   ...         ...        ...        ...
# 283053  Санкт-Петербург   1.0  COL_280479  59.936954  30.356383
# 283054      Калининград   3.0  COL_280518  54.729233  20.514968
# 283055         Кемерово   1.0  COL_280529  55.360680  86.081460
# 283056            Киров   1.0  COL_280637  58.592915  49.677439
# 283057            Киров   1.0  COL_280637  58.592915  49.677439
#
#         osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 0                                 4                           19
# ...

# %%
da = {}
da.keys
# Out:
# <function dict.keys>

# %%
train_df[train_df['city'] == 'Екатеринбург']
# Out:
#                 city floor          id        lat        lng  \
# 9       Екатеринбург   NaN       COL_9  56.833660  60.635742
# 13      Екатеринбург   NaN      COL_13  56.765465  60.710392
# 24      Екатеринбург   NaN      COL_24  56.852695  60.646065
# 38      Екатеринбург   NaN      COL_38  56.781548  60.550880
# 39      Екатеринбург   NaN      COL_39  56.795437  60.509350
# ...              ...   ...         ...        ...        ...
# 279766  Екатеринбург     7  COL_278319  56.823689  60.609137
# 279768  Екатеринбург     7  COL_278324  56.823689  60.609502
# 279769  Екатеринбург     7  COL_278325  56.823689  60.608076
# 279770  Екатеринбург     6  COL_278336  56.817951  60.615535
# 279771  Екатеринбург     6  COL_278338  56.817951  60.614592
#
#         osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# 9                                 5                           66
# 13                                0                            4
# ...

# %%
['a', 'b'][:-1]
# Out:
# ['a']

# %%
b[b.eq('17700[4]').any(1)]
# Out:
#           city floor          id        lat        lng  \
# 93337   Кукмор   NaN    COL_4648  56.174274  50.872395
# 93431   Кукмор   NaN    COL_8008  56.176502  50.876600
# 95321   Кукмор   NaN   COL_62808  56.182556  50.924520
# 95328   Кукмор   NaN   COL_63029  56.184080  50.893030
# 95644   Кукмор   NaN   COL_71125  56.178284  50.879680
# 96988   Кукмор   NaN  COL_109151  56.186600  50.893982
# 97475   Кукмор   NaN  COL_126504  56.201237  50.832558
# 98793   Кукмор   NaN  COL_164512  56.178284  50.879680
# 98987   Кукмор   NaN  COL_170875  56.190823  50.869602
# 99507   Кукмор   NaN  COL_192729  56.190636  50.907920
# 99643   Кукмор   NaN  COL_197648  56.191140  50.869330
# 100257  Кукмор   NaN  COL_220158  56.190823  50.869602
# 101251  Кукмор   NaN  COL_248515  56.201237  50.832558
# 101285  Кукмор   NaN  COL_249961  56.178284  50.879680
# 101495  Кукмор   NaN  COL_256847  56.192238  50.918415
# 101791  Кукмор   NaN  COL_266122  56.182556  50.924520
#
# ...
